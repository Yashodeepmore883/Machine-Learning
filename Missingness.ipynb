# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b1119fb-435d-4dce-bc87-99cf6af39f29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b1119fb-435d-4dce-bc87-99cf6af39f29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('salary-updated.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 397

# %%
df.shape
# Out:
# (397, 6)

# %%
df.head()
# Out:
#        rank discipline  yrs.since.phd  yrs.service gender  salary
# 0      Prof          B             19           18   Male  139750
# 1      Prof          B             20           16   Male  173200
# 2  AsstProf          B              4            3   Male   79750
# 3      Prof          B             45           39   Male  115000
# 4      Prof          B             40           41   Male  141500

# %%
df.tail()
# Out:
#          rank discipline  yrs.since.phd  yrs.service gender  salary
# 392      Prof          A             33           30   Male  103106
# 393      Prof          A             31           19   Male  150564
# 394      Prof          A             42           25   Male  101738
# 395      Prof          A             25           15   Male   95329
# 396  AsstProf          A              8            4   Male   81035

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   gender         397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
df.describe(include=object)
# Out:
#         rank discipline gender
# count    397        397    397
# unique     3          2      2
# top     Prof          B   Male
# freq     266        216    358

# %%
df["rank"].value_counts()
# Out:
# Prof         266
# AsstProf      67
# AssocProf     64
# Name: rank, dtype: int64

# %%
df["rank"].unique()
# Out:
# array(['Prof', 'AsstProf', 'AssocProf'], dtype=object)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cdc00c95-a848-4d3c-a183-28865244ca1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cdc00c95-a848-4d3c-a183-28865244ca1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv('salary-updated2.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     394 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         393 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df2.isnull()
# Out:
#       rank  discipline  yrs.since.phd  yrs.service  gender  salary
# 0    False       False          False        False   False   False
# 1    False       False          False        False   False   False
# 2    False       False          False        False   False   False
# 3    False       False          False        False   False   False
# 4    False       False          False         True   False   False
# ..     ...         ...            ...          ...     ...     ...
# 392  False       False          False        False   False   False
# 393  False       False          False        False   False   False
# 394  False       False          False        False   False   False
# 395  False       False          False        False   False   False
# 396  False       False          False        False   False   False
#
# [397 rows x 6 columns]

# %%
df2.isnull().sum()
# Out:
# rank             0
# discipline       3
# yrs.since.phd    5
# yrs.service      4
# gender           0
# salary           4
# dtype: int64

# %%
df3 = df2.dropna(axis=0)

# %%
len(df2)
# Out:
# 397

# %%
len(df3)
# Out:
# 382

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     394 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         393 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 382 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           382 non-null    object
#  1   discipline     382 non-null    object
#  2   yrs.since.phd  382 non-null    float64
#  3   yrs.service    382 non-null    float64
#  4   gender         382 non-null    object
#  5   salary         382 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 20.9+ KB

# %%
df4=df2
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     394 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         393 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df4["discipline"].fillna("A", inplace = True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         393 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df4["salary"].fillna(10000, inplace = True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         397 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df5=df4
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    393 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         397 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df5["yrs.service"].fillna(method ='ffill', inplace = True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  392 non-null    float64
#  3   yrs.service    397 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         397 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB

# %%
df5.interpolate(method ='linear', limit_direction ='forward',inplace = True)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    float64
#  3   yrs.service    397 non-null    float64
#  4   gender         397 non-null    object
#  5   salary         397 non-null    float64
# dtypes: float64(3), object(3)
# memory usage: 18.7+ KB
